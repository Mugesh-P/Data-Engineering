# %%
import boto3
import pandas as pd
# import s3fs

# s3 = boto3.resource('s3')
# s3.Object("mugesh-de-load-practice", "vehicle_dataset").put(Body=open("C:\\Users\\naina\\Downloads\\vehicles_dataset.csv", 'rb'))

# data = pd.read_csv("vehicles_dataset.csv")
# data.to_csv("S3://mugesh-de-load-practice/vehicles_dataset.csv")

s3 = boto3.resource(
    service_name='s3',
    region_name='eu-north-1',
    aws_access_key_id='AKIAXYKJWFZRIBEOC2MQ',
    aws_secret_access_key='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')
s3.meta.client.upload_file('D:\\DE\\Dataset\\vehicles_dataset.csv', "mugesh-de-load-practice", "vehicle_dataset.csv")

# %%
# importing key and secret key directly to the environment 

import os

os.environ["AWS_DEFAULT_REGION"] = 'eu-north-1'
os.environ["AWS_ACCESS_KEY_ID"] = 'AKIAXYKJWFZRIBEOC2MQ'
os.environ["AWS_SECRET_ACCESS_KEY"]= 'hVoJVJt7CHpiSWtaqV87BDN9147keC7AsBjyegYk'

# %%
dummy_data1 = pd.DataFrame({'one':[1,2,3], 'two':[2,3,4], 'alpha':['a', 'b', 'c']})
dummy_data2 = pd.DataFrame({'a':['a', 'b', 'c'], 'z':['x', 'y', 'z'], 'numeric':[1, 2, 3]})

dummy_data1.to_csv('dummy_data1.csv')
dummy_data2.to_csv('dummy_data2.csv')

# %%
# data_s3 = boto3.client('s3', aws_access_key_id="AKIAXYKJWFZRIBEOC2MQ", aws_secret_access_key="hVoJVJt7CHpiSWtaqV87BDN9147keC7AsBjyegYk")

# uploading the file into s3 bucket

s3.Bucket('mugesh-de-load-practice').upload_file(Filename='dummy_data1.csv', Key='dummy_data1.csv')
s3.Bucket('mugesh-de-load-practice').upload_file(Filename='dummy_data2.csv', Key='dummy_data2.csv')

# %%
obj = s3.Bucket("mugesh-de-load-practice").Object("vehicle_dataset.csv").get()
vehicles_data = pd.read_csv(obj['Body'], index_col=0)

# %%
vehicles_data
# Out:
#                                                                                       description  \
# name
# 2024 Jeep Wagoneer Series II                    \n      \n        Heated Leather Seats, Nav Sy...
# 2024 Jeep Grand Cherokee Laredo                 Al West is committed to offering every custome...
# 2024 GMC Yukon XL Denali                                                                      NaN
# 2023 Dodge Durango Pursuit                      White Knuckle Clearcoat 2023 Dodge Durango Pur...
# 2024 RAM 3500 Laramie                           \n      \n        2024 Ram 3500 Laramie Billet...
# ...                                                                                           ...
# 2024 Mercedes-Benz Sprinter 2500 Standard Roof  2024 Mercedes-Benz Sprinter 2500 Cargo 144 WB ...
# 2024 Dodge Hornet Hornet R/T Plus Eawd          Dealer Comments +++ Price Ends 5/31/2024 +++ A...
# ...

# %%
# printing all the buckets connected to s3

for bucket in s3.buckets.all():
    print(bucket.name)
    
for obj in s3.Bucket('mugesh-de-load-practice').objects.all():
    print(obj)
# Out:
# mugesh-de-load-practice
# s3.ObjectSummary(bucket_name='mugesh-de-load-practice', key='dummy_data1.csv')
# s3.ObjectSummary(bucket_name='mugesh-de-load-practice', key='dummy_data2.csv')
# s3.ObjectSummary(bucket_name='mugesh-de-load-practice', key='vehicle_dataset.csv')
